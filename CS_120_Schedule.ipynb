# %%
import pandas as pa
import datetime as dt
pa.set_option('max_colwidth', 200)

# %%
first_day = dt.date(2021, 8, 23)

# %%
holidays = [dt.date(2021, 9, 6) ]
turkey_break_start = dt.date(2021, 11, 24)
turkey_break_end = dt.date(2021, 11, 28)
turkey_break_delta = turkey_break_end - turkey_break_start
holidays += [ turkey_break_start + dt.timedelta(i) for i in range(turkey_break_delta.days+1)]

# %%
last_day = dt.date(2021, 12, 3)

# %%
final_exam = dt.date(2021, 12, 6)

# %%
semester_length = last_day - first_day
semester_length
# Out:
# datetime.timedelta(days=102)

# %%
class_days = []
for i in range((semester_length.days //7 + 1)):
    class_days += [first_day + dt.timedelta(i*7), first_day + dt.timedelta(i*7+2), first_day + dt.timedelta(i*7+4)]
class_days += [final_exam]

# %%
schedule = pa.DataFrame(class_days, columns = ['Day'])
weekday_dict = {0:'Monday', 1:'Tuesday', 2:'Wednesday', 3:'Thursday', 4:'Friday', 
                5:'Saturday', 6:'Sunday'}
for i in range(schedule.shape[0]):
    schedule.loc[i,'Week_Day'] = schedule.loc[i, 'Day'].weekday()
schedule.Week_Day = schedule.Week_Day.map(weekday_dict)

# %%
for holiday in holidays:
    schedule.loc[schedule.Day==holiday, 'Title'] = 'No Class - University Holiday'

# %%
def add_day(title='', description='', notes=''):
    global schedule
    global day
    
    while schedule.loc[day, 'Day'] in holidays:
        day += 1
    if day >= schedule.shape[0]:
        print('Error to many days')
        return 'ERROR'
    else:
        schedule.loc[day, 'Title'] = title
        schedule.loc[day, 'Description'] = description
        schedule.loc[day, 'Notes'] = notes
        
        day += 1

# %%
day = 0

# Introduction - our first program

add_day('Introduction to Python / Jupyter', 
        'Variables', 'Compute N! and (2N-1)!!; and how many primes are there less than N?')

add_day('Variables and Functions', 'Types of variables and writing functions')

add_day('Lab Day:  Find N! and (2N-1)!!')

add_day('Local and Global Variables')

add_day('Conditionals and Recursion')

add_day('Lab Day:  Approximate a square root')

add_day('Introduction to modules', 'Numpy and Matplotlib')

add_day('Lab Day: How fast does factorial grow?')

add_day('Iterations', 'For and While')

add_day('Iterations', 'Iterator Objects')

add_day('Lab Day: ')

add_day('Strings', 'Arguably the thing Python does best')

add_day('Strings')

add_day('Lab Day: Analyzing Hamlet')

add_day('Lists and Tuples', 'Mutable versus Immutaable', 'and why we would care')

add_day('Lists and Tuples', 'Slices, map, filter, reduce')

add_day('Lab Day: How many primes are there less than N?')

add_day('Lab Day: Find the derrivative of a polynomial')

add_day('Dictionaries')

add_day('Lab Day: Algebra of Permutations')


schedule
# Out:
#            Day   Week_Day                                            Title  \
# 0   2021-08-23     Monday                 Introduction to Python / Jupyter
# 1   2021-08-25  Wednesday                          Variables and Functions
# 2   2021-08-27     Friday                   Lab Day:  Find N! and (2N-1)!!
# 3   2021-08-30     Monday                       Local and Global Variables
# 4   2021-09-01  Wednesday                       Conditionals and Recursion
# 5   2021-09-03     Friday              Lab Day:  Approximate a square root
# 6   2021-09-06     Monday                    No Class - University Holiday
# 7   2021-09-08  Wednesday                          Introduction to modules
# 8   2021-09-10     Friday           Lab Day: How fast does factorial grow?
# 9   2021-09-13     Monday                                       Iterations
# 10  2021-09-15  Wednesday                                       Iterations
# 11  2021-09-17     Friday                                        Lab Day:
# 12  2021-09-20     Monday                                          Strings
# 13  2021-09-22  Wednesday                                          Strings
# 14  2021-09-24     Friday                        Lab Day: Analyzing Hamlet
# 15  2021-09-27     Monday                                 Lists and Tuples
# 16  2021-09-29  Wednesday                                 Lists and Tuples
# 17  2021-10-01     Friday  Lab Day: How many primes are there less than N?
# 18  2021-10-04     Monday    Lab Day: Find the derrivative of a polynomial
# 19  2021-10-06  Wednesday                                     Dictionaries
# 20  2021-10-08     Friday                 Lab Day: Algebra of Permutations
# 21  2021-10-11     Monday                                              NaN
# 22  2021-10-13  Wednesday                                              NaN
# 23  2021-10-15     Friday                                              NaN
# 24  2021-10-18     Monday                                              NaN
# 25  2021-10-20  Wednesday                                              NaN
# 26  2021-10-22     Friday                                              NaN
# 27  2021-10-25     Monday                                              NaN
# 28  2021-10-27  Wednesday                                              NaN
# 29  2021-10-29     Friday                                              NaN
# 30  2021-11-01     Monday                                              NaN
# 31  2021-11-03  Wednesday                                              NaN
# 32  2021-11-05     Friday                                              NaN
# 33  2021-11-08     Monday                                              NaN
# 34  2021-11-10  Wednesday                                              NaN
# 35  2021-11-12     Friday                                              NaN
# 36  2021-11-15     Monday                                              NaN
# 37  2021-11-17  Wednesday                                              NaN
# 38  2021-11-19     Friday                                              NaN
# 39  2021-11-22     Monday                                              NaN
# 40  2021-11-24  Wednesday                    No Class - University Holiday
# 41  2021-11-26     Friday                    No Class - University Holiday
# 42  2021-11-29     Monday                                              NaN
# 43  2021-12-01  Wednesday                                              NaN
# 44  2021-12-03     Friday                                              NaN
# 45  2021-12-06     Monday                                              NaN
#
#                                  Description  \
# 0                                  Variables
# 1   Types of variables and writing functions
# 2
# 3
# 4
# 5
# 6                                        NaN
# 7                       Numpy and Matplotlib
# 8
# 9                              For and While
# 10                          Iterator Objects
# 11
# 12       Arguably the thing Python does best
# 13
# 14
# 15                 Mutable versus Immutaable
# 16               Slices, map, filter, reduce
# 17
# 18
# 19
# 20
# 21                                       NaN
# 22                                       NaN
# 23                                       NaN
# 24                                       NaN
# 25                                       NaN
# 26                                       NaN
# 27                                       NaN
# 28                                       NaN
# 29                                       NaN
# 30                                       NaN
# 31                                       NaN
# 32                                       NaN
# 33                                       NaN
# 34                                       NaN
# 35                                       NaN
# 36                                       NaN
# 37                                       NaN
# 38                                       NaN
# 39                                       NaN
# 40                                       NaN
# 41                                       NaN
# 42                                       NaN
# 43                                       NaN
# 44                                       NaN
# 45                                       NaN
#
#                                                                   Notes
# 0   Compute N! and (2N-1)!!; and how many primes are there less than N?
# 1
# 2
# 3
# 4
# 5
# 6                                                                   NaN
# 7
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 15                                                and why we would care
# 16
# 17
# 18
# 19
# 20
# 21                                                                  NaN
# 22                                                                  NaN
# 23                                                                  NaN
# 24                                                                  NaN
# 25                                                                  NaN
# 26                                                                  NaN
# 27                                                                  NaN
# 28                                                                  NaN
# 29                                                                  NaN
# 30                                                                  NaN
# 31                                                                  NaN
# 32                                                                  NaN
# 33                                                                  NaN
# 34                                                                  NaN
# 35                                                                  NaN
# 36                                                                  NaN
# 37                                                                  NaN
# 38                                                                  NaN
# 39                                                                  NaN
# 40                                                                  NaN
# 41                                                                  NaN
# 42                                                                  NaN
# 43                                                                  NaN
# 44                                                                  NaN
# 45                                                                  NaN
